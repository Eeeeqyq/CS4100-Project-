# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# # Found this interesting craiglist dialogue dataset from kaggle

# %%
df = pd.read_csv('craigslist_bargains_train.csv')
print("1")
print(df.head())
print("2")
print(df.columns)
print("3")
print(df.info())
print("4")
print(df.shape)
# Out:
# 1
#                                                 text  label class_name  \
# 0  Buyer: Hey there!\nSeller: Hello. Are you inte...      3  furniture
# 1                                       Buyer: hello      0       bike
# 2  Seller: Good evening\nBuyer: Hi! I would love ...      1        car
# 3  Seller: Hey there.\nBuyer: I'm very inttereste...      4    housing
# 4  Buyer: Hello, I like your windmill and might b...      3  furniture
#
#    LLM_label
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 2
# Index(['text', 'label', 'class_name', 'LLM_label'], dtype='str')
# 3
# <class 'pandas.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   text        2947 non-null   str
#  1   label       3000 non-null   int64
#  2   class_name  3000 non-null   str
#  3   LLM_label   0 non-null      float64
# dtypes: float64(1), int64(1), str(2)
# memory usage: 93.9 KB
# None
# 4
# (3000, 4)
